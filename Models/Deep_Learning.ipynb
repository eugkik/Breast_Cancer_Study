# %%
import pandas as pd
import numpy as np

# %%
# Read the csv file into a pandas DataFrame
df = pd.read_csv('../Data/df_clinical_ML_filtered.csv')
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    age_at_diagnosis  chemotherapy  neoplasm_histologic_grade  hormone_therapy  \
# 1             43.19             0                        3.0                1
# 2             48.87             1                        2.0                1
# 3             47.68             1                        2.0                1
# 4             76.97             1                        3.0                1
# 5             78.77             0                        3.0                1
#
#    lymph_nodes_examined_positive  mutation_count  overall_survival  \
# 1                              0             2.0                 1
# 2                              1             2.0                 0
# 3                              3             1.0                 1
# 4                              8             2.0                 0
# 5                              0             4.0                 0
#
#    radio_therapy  tumor_size  tumor_stage  encoded_type_of_breast_surgery  \
# 1              1        10.0          1.0                               0
# 2              0        15.0          2.0                               1
# 3              1        25.0          2.0                               1
# 4              1        40.0          2.0                               1
# 5              1        31.0          4.0                               1
#
#    encoded_cancer_type_detailed  encoded_cellularity  \
# 1                             1                    0
# 2                             1                    0
# 3                             4                    2
# 4                             4                    0
# 5                             1                    2
#
#    encoded_pam50_+_claudin-low_subtype  encoded_er_status  \
# 1                                    2                  1
# 2                                    3                  1
# 3                                    3                  1
# 4                                    3                  1
# 5                                    3                  1
#
#    encoded_her2_status  encoded_tumor_other_histologic_subtype  \
# 1                    0                                       0
# 2                    0                                       0
# 3                    0                                       4
# 4                    0                                       4
# 5                    0                                       0
#
#    encoded_inferred_menopausal_state  encoded_integrative_cluster  \
# 1                                  1                            4
# 2                                  1                            3
# 3                                  1                           10
# 4                                  0                           10
# 5                                  0                            8
#
#    encoded_pr_status
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# 5                  1

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop(['overall_survival'], axis=1)

# %%
# Set X and y variables
y = df['overall_survival']
X = selected_features

print(X.shape, y.shape)
# Out:
# (1017, 19) (1017,)

# %%
# Split data into training and testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
#       age_at_diagnosis  chemotherapy  neoplasm_histologic_grade  \
# 196              51.74             0                        2.0
# 997              68.93             0                        2.0
# 1028             81.57             0                        2.0
# 407              52.98             0                        1.0
# 1052             51.25             1                        3.0
#
#       hormone_therapy  lymph_nodes_examined_positive  mutation_count  \
# 196                 1                              0             4.0
# 997                 1                              1             8.0
# 1028                1                              3            11.0
# 407                 0                              0            10.0
# 1052                1                              1             7.0
#
#       radio_therapy  tumor_size  tumor_stage  encoded_type_of_breast_surgery  \
# 196               0        22.0          2.0                               1
# 997               0        18.0          2.0                               1
# 1028              0        35.0          2.0                               1
# 407               1        10.0          1.0                               0
# 1052              1        25.0          2.0                               1
#
#       encoded_cancer_type_detailed  encoded_cellularity  \
# 196                              4                    2
# 997                              1                    0
# 1028                             1                    0
# 407                              1                    0
# 1052                             1                    2
#
#       encoded_pam50_+_claudin-low_subtype  encoded_er_status  \
# 196                                     2                  1
# 997                                     1                  1
# 1028                                    2                  1
# 407                                     2                  1
# 1052                                    1                  0
#
#       encoded_her2_status  encoded_tumor_other_histologic_subtype  \
# 196                     0                                       4
# 997                     1                                       0
# 1028                    0                                       0
# 407                     0                                       7
# 1052                    0                                       0
#
#       encoded_inferred_menopausal_state  encoded_integrative_cluster  \
# 196                                   0                            9
# 997                                   0                            6
# 1028                                  0                            9
# 407                                   0                            9
# 1052                                  0                            5
#
#       encoded_pr_status
# 196                   1
# 997                   1
# 1028                  1
# 407                   1
# 1052                  0

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and layers
model = Sequential()
model.add(Dense(units = 100, activation ='relu', input_dim=19))
model.add(Dense(units = 100, activation ='relu'))
model.add(Dense(units = 3, activation='softmax'))

# %%
# compile the model
model.compile(optimizer ='adam',
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               2000
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 12,403
# Trainable params: 12,403
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs= 100,
    shuffle= True,
    verbose= 2
)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-547ebf7e8d99> in <module>
#       1 # fit the model
# ----> 2 model.fit(
#       3     X_train_scaled,
#       4     y_train_categorical,
#       5     epochs= 100,
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\engine\training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\engine\training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\engine\training.py", line 809, in train_step
#         loss = self.compiled_loss(
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\losses.py", line 1664, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\nick\anaconda3\lib\site-packages\keras\backend.py", line 4994, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 2) and (None, 3) are incompatible
